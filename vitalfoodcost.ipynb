# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/food-prices/Food Prices.csv

# %%
#plot
import matplotlib.pyplot as plt

#import math
import math

#import seaborn
import seaborn as sns; sns.set_theme()

# %%
#read the .csv and display the info
df_food = pd.read_csv ('/kaggle/input/food-prices/Food Prices.csv')
df_food.info()
df_food
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              1200 non-null   object
#  1   Year                 1200 non-null   int64
#  2   Month                1200 non-null   int64
#  3   Food Item            1200 non-null   object
#  4   Unit of Measurement  1200 non-null   object
#  5   Average Price        1200 non-null   float64
#  6   Currency             1200 non-null   object
#  7   Price in USD         1200 non-null   float64
#  8   Availability         1200 non-null   int64
#  9   Quality              1200 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 93.9+ KB
#        Country   Year   Month  Food Item  Unit of Measurement  Average Price   \
# 0     Australia   2018       1      Bread                Loaf            2.20
# ...

# %%
#Display the Country
UnqCountry = df_food['Country '].unique()
print ("The countries we analyzed are ", UnqCountry)
# Out:
# The countries we analyzed are  ['Australia' 'Sweden' 'Japan' 'South Africa' 'Canada']

# %%
#Display the Year
UnqYear = df_food['Year '].unique()
print ("The years we analyzed are ", UnqYear)
# Out:
# The years we analyzed are  [2018 2019 2020 2021 2022]

# %%
#Display the Food Item
UnqItem = df_food['Food Item '].unique()
print ("The Food Item we analyzed are ", UnqItem)
# Out:
# The Food Item we analyzed are  ['Bread' 'Milk' 'Eggs' 'Potatoes']

# %%
#Average of price
df_avgPrice=df_food.groupby(['Country ','Year ','Food Item '])['Average Price '].mean().round()

df=pd.DataFrame(df_avgPrice)
print(df)
# Out:
#                             Average Price
# Country   Year  Food Item
# Australia 2018  Bread                  2.0
#                 Eggs                   3.0
#                 Milk                   1.0
#                 Potatoes               3.0
#           2019  Bread                  2.0
# ...                                    ...
# Sweden    2021  Potatoes              12.0
#           2022  Bread                 24.0
#                 Eggs                  34.0
#                 Milk                  14.0
#                 Potatoes              14.0
#
# [100 rows x 1 columns]

# %%
# Plotting a box plot to visualize the distribution of average prices for different food items
plt.figure(figsize=(12, 8))
sns.boxplot(data=df_food, x='Food Item ', y='Average Price ',hue='Year ', palette='Set2')
plt.xlabel('Food Item')
plt.ylabel('Average Price (AUD)')
plt.title('Distribution of Average Prices for Different Food Items')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()
